# %% [markdown]
# <a href="https://colab.research.google.com/github/xuziyue/tensorflow-models/blob/main/time_series_common_patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_series(time_series, format="-", start=0, end=None, label=None):
  plt.plot(time[start:end], series[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("Value")
  if label:
    plt.legend(fontsize=14)
  plt.grid(True)

# %%
def trend(time, slope=0):
  return slope * time

# %%
time = np.arange(4*365 + 1)
baseline = 10
series = baseline + trend(time, 0.1)

plt.figure(figsize=(10,6))
plot_series(time, series)
plt.show()

# %%
def seasonal_pattern(season_time):
  return np.where(season_time < 0.4, np.cos(season_time*2*np.pi), 1/np.exp(3*season_time))

def seasonality(time, period, amplitute=1, phase=0):
  season_time = ((time + phase) % period) / period
  return amplitute * seasonal_pattern(season_time)

# %%
amp = 40
series = seasonality(time, 365, amp)
series2 = seasonality(time, 365, amp, 30)

plt.figure(figsize=(10, 6))
plot_series(time, series)
plot_series(time, series2)
plt.show()
